# %%
# Imports and basic setup
import re
from pathlib import Path
import pandas as pd
from pathlib import Path
from IPython.display import display

pd.options.display.max_columns = 50
pd.options.display.width = 140

print('pandas', pd.__version__)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pz/lfvpvb6d2wbdsny70113by7w0000gn/T/ipykernel_30288/2359362419.py", line 4, in <module>
#     import pandas as pd
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/opt/anaconda3/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pz/lfvpvb6d2wbdsny70113by7w0000gn/T/ipykernel_30288/2359362419.py", line 4, in <module>
#     import pandas as pd
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pz/lfvpvb6d2wbdsny70113by7w0000gn/T/ipykernel_30288/2359362419.py", line 4, in <module>
#     import pandas as pd
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py", line 52, in <module>
#     from pandas.core import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/opt/anaconda3/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/lib/python3.12/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pz/lfvpvb6d2wbdsny70113by7w0000gn/T/ipykernel_30288/2359362419.py", line 4, in <module>
#     import pandas as pd
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py", line 66, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/masked.py", line 61, in <module>
#     from pandas.core import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/opt/anaconda3/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/lib/python3.12/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# pandas 2.3.2

# %%
# Read file and collect !Sample_ header lines
# Read directly from the absolute path you provided to avoid any cwd issues
relative_path = Path.cwd().parent
series_path = Path.cwd().parent / 'data/geo/GSE213478_series_matrix.txt' #relative path
text = series_path.read_text(encoding='utf-8')
lines = text.splitlines()
sample_lines = [L for L in lines if L.startswith('!Sample_')]
print('Header sample lines found:', len(sample_lines))
# Out:
# Header sample lines found: 45

# %%
# Parse header lines into keys and lists of values
sample_fields = {}
for L in sample_lines:
    parts = L.split('\t')
    key = parts[0].lstrip('!')
    # strip surrounding quotes and whitespace from values
    vals = [v.strip().strip('"') for v in parts[1:]]
    sample_fields.setdefault(key, []).append(vals)

# Determine number of samples
if 'Sample_geo_accession' in sample_fields:
    n = len(sample_fields['Sample_geo_accession'][0])
elif 'Sample_title' in sample_fields:
    n = len(sample_fields['Sample_title'][0])
else:
    raise RuntimeError('No sample id lines found in the series_matrix header')

# Helper to make safe column names from Sample_* keys
def safe_col(k):
    # remove leading 'Sample_' and replace non-alnum with '_'
    s = k.replace('Sample_','')
    import re as _re
    return _re.sub('[^0-9a-zA-Z]+','_', s).strip('_')

records = []
for i in range(n):
    rec = {}
    rec['GSM'] = sample_fields.get('Sample_geo_accession', [['']*n])[0][i] if 'Sample_geo_accession' in sample_fields else ''
    rec['title'] = sample_fields.get('Sample_title', [['']*n])[0][i] if 'Sample_title' in sample_fields else ''
    # Aggregate characteristics lines (there can be multiple "Sample_characteristics_ch1" lines)
    char_parts = []
    for k, vlist in sample_fields.items():
        if k.startswith('Sample_characteristics'):
            for line_vals in vlist:
                if i < len(line_vals) and line_vals[i] != '':
                    char_parts.append(line_vals[i])
    rec['characteristics'] = ' | '.join(char_parts)
    # Also capture other Sample_* fields (e.g., source name, organism, library, etc.) as separate columns
    for k, vlist in sample_fields.items():
        if k in ('Sample_geo_accession','Sample_title') or k.startswith('Sample_characteristics'):
            continue
        # take the first line block for this key (most Sample_* keys have only one block)
        try:
            val = vlist[0][i] if i < len(vlist[0]) else ''
        except Exception:
            # defensive fallback
            val = ''
        if val != '':
            rec[safe_col(k)] = val
    records.append(rec)

len(records)
# Out:
# 987

# %%
# Extract tissue, age, sex, donor_id from characteristics using regex (case-insensitive)
re_tissue = re.compile(r'(?i)tissue: *([^|;]+)')
re_age = re.compile(r'(?i)age: *([0-9]+(?:-[0-9]+)?)')
# accept numeric encodings (1/2) as well as textual M/F or male/female
re_sex = re.compile(r'(?i)sex: *([12]|[MFmf]|male|female)')
# prefer collaborator_participant_id (e.g., GTEX-...) or participant_id, then fall back to generic labels
re_subject_collab = re.compile(r'(?i)collaborator_participant_id: *([A-Za-z0-9_-]+)')
re_subject_part = re.compile(r'(?i)participant_id: *([A-Za-z0-9_-]+)')
re_subject_generic = re.compile(r'(?i)(?:subjectid|subject_id|patient|patient_id|donor): *([A-Za-z0-9_-]+)')

def parse_age_raw(ar):
    if not ar:
        return '', None
    if '-' in ar:
        try:
            a,b = [float(x) for x in ar.split('-')[:2]]
            return ar, (a+b)/2
        except:
            return ar, None
    try:
        v = float(ar)
        return ar, v
    except:
        return ar, None

out = []
for r in records:
    ch = r.get('characteristics','') or ''
    tissue = ''
    age_raw = ''
    age_num = None
    sex = ''
    donor = ''
    m = re_tissue.search(ch)
    if m: tissue = m.group(1).strip()
    m = re_age.search(ch)
    if m:
        age_raw, age_num = parse_age_raw(m.group(1).strip())
    m = re_sex.search(ch)
    if m:
        s = m.group(1).strip()
        # map numeric codes to letters if needed
        if s in ('1','2'):
            sex = 'M' if s == '1' else 'F'
        else:
            s2 = s[0].upper() if s else ''
            if s2 in ('M','F'): sex = s2
    # donor id: prefer collaborator_participant_id (GTEX id), then participant_id, then generic patterns
    m = re_subject_collab.search(ch)
    if m:
        donor = m.group(1).strip()
    else:
        m = re_subject_part.search(ch)
        if m:
            donor = m.group(1).strip()
        else:
            m = re_subject_generic.search(ch)
            if m: donor = m.group(1).strip()
    # also pull any additional columns we captured earlier (source_name, organism, etc.)
    rec = {
        'GSM': r.get('GSM',''),
        'title': r.get('title',''),
        'tissue': tissue,
        'age_raw': age_raw,
        'age_num': age_num,
        'sex': sex,
        'donor_id': donor,
        'characteristics': ch,
    }
    # include any extra Sample_* columns that were recorded (already added to record keys)
    for k,v in r.items():
        if k in ('GSM','title','characteristics'):
            continue
        if k not in rec:
            rec[k] = v
    out.append(rec)

df = pd.DataFrame(out)
# coerce age_num to numeric
df['age_num'] = pd.to_numeric(df['age_num'], errors='coerce')
df.shape
# Out:
# (987, 37)

# %%
# Robustly parse key:value pairs from 'characteristics' into separate columns
import re
import pandas as pd
from collections import defaultdict

def normalize_colname(k):
    k = k.strip()
    # common synonyms
    k = re.sub(r'(?i)collaborator[_ ]?participant[_ ]?id', 'collaborator_participant_id', k)
    k = re.sub(r'(?i)participant[_ ]?id', 'participant_id', k)
    # make safe snake_case names
    k = re.sub(r'[^0-9a-zA-Z]+', '_', k).strip('_').lower()
    return k

def parse_characteristics_text(s):
    # returns dict of parsed key->value
    if not s or pd.isna(s):
        return {}
    # split on common separators: ' | ' and ';' and similar
    parts = re.split(r'\s*\|\s*|\s*;\s*', s)
    out = {}
    for p in parts:
        if not p:
            continue
        # many items are 'key: value' or 'key = value' or just 'value'
        if ':' in p:
            k, v = p.split(':', 1)
        elif '=' in p:
            k, v = p.split('=', 1)
        else:
            # fallback: put into a generic 'note' field
            k, v = 'note', p
        k = normalize_colname(k)
        v = v.strip().strip('"').strip()
        if k in out:
            out[k] = out[k] + ' | ' + v
        else:
            out[k] = v
    return out

# Apply parsing to every row and expand to columns
parsed_dicts = [parse_characteristics_text(ch) for ch in df['characteristics'].fillna('')]
parsed_df = pd.DataFrame(parsed_dicts)

# Merge parsed columns into df without overwriting existing explicit columns unless parsed value is non-empty
for col in parsed_df.columns:
    if col in df.columns:
        df[col] = df[col].astype('object').fillna(parsed_df[col])
    else:
        df[col] = parsed_df[col]

# Recompute/normalize key columns from newly parsed fields if available

def coerce_age_from_fields(row):
    for candidate in ('age','age_raw','age_y','age_years'):
        if candidate in row and pd.notna(row[candidate]) and str(row[candidate]).strip() != '':
            ar = str(row[candidate]).strip()
            if '-' in ar:
                try:
                    a,b = [float(x) for x in ar.split('-')[:2]]
                    return (ar, (a+b)/2)
                except:
                    return (ar, None)
            try:
                v = float(re.sub(r'[^0-9.]','', ar))
                return (ar, v)
            except:
                return (ar, None)
    return (row.get('age_raw',''), row.get('age_num', None))


def coerce_sex_from_fields(row):
    for candidate in ('sex','gender'):
        if candidate in row and pd.notna(row[candidate]) and str(row[candidate]).strip() != '':
            s = str(row[candidate]).strip()
            if s in ('1','2'):
                return 'M' if s=='1' else 'F'
            s2 = s[0].upper()
            if s2 in ('M','F'):
                return s2
    return row.get('sex','')

age_results = df.apply(coerce_age_from_fields, axis=1)
df['age_raw_parsed'] = [x[0] for x in age_results]
df['age_num_parsed'] = [x[1] for x in age_results]

df['sex_parsed'] = df.apply(coerce_sex_from_fields, axis=1)

# Normalize tissue simple cleaning
import re as _re

def normalize_tissue(t):
    if pd.isna(t) or str(t).strip()=='':
        return ''
    s = str(t).strip()
    s = _re.sub(r'\s+', ' ', s)
    return s

df['tissue'] = df['tissue'].fillna('').apply(normalize_tissue)

# Preview and counts
print('Preview of expanded columns:')
display(df.head(10))
print('\nTissue counts (top 20):')
print(df['tissue'].value_counts(dropna=False).head(20))

# Write enriched CSV
outp = relative_path / 'data/geo/gse213478_metadata_parsed_enriched.csv'
df.to_csv(outp, index=False)
print('\nWrote enriched CSV:', outp)

# %% [markdown]
# ### Improve characteristics parsing
#
# This cell expands `characteristics` (free text) into key:value columns. It handles several separators (`|`, `;`) and common key formats, normalizes column names to snake_case, and repairs/overrides `tissue`, `age_num`, and `sex` when clearer values are present in the extracted fields. Use this to produce a richer `gse213478_metadata_parsed_enriched.csv`.

# %%
# Save CSV and show preview/summary
outp = relative_path / 'data/geo/gse213478_metadata_parsed.csv'
outp.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(outp, index=False)
print('Wrote:', outp.resolve())
display(df.head(20))
print('\nTissue counts:')
print(df['tissue'].value_counts(dropna=False).head(30))
print('\nMissingness summary (age/sex):')
print('age_num missing:', df['age_num'].isna().sum(), '/', len(df))
print('sex missing:', df['sex'].eq('').sum(), '/', len(df))
# Out:
# Wrote: /Users/user/BIOF_3001/Project/data/geo/gse213478_metadata_parsed.csv
#            GSM                     title                   tissue age_raw  age_num sex    donor_id  \
# 0   GSM6586938  GTEX-11EM3-1326-SM-GW24C  Breast - Mammary Tissue   20-29     24.5   F  GTEX-11EM3
# 1   GSM6586939  GTEX-11EMC-2026-SM-GW242  Breast - Mammary Tissue   60-69     64.5   F  GTEX-11EMC
# 2   GSM6586940  GTEX-11GSP-0926-SM-GW21X  Breast - Mammary Tissue   60-69     64.5   F  GTEX-11GSP
# 3   GSM6586941  GTEX-13D11-1026-SM-GW1D7  Breast - Mammary Tissue   50-59     54.5   F  GTEX-13D11
# 4   GSM6586942  GTEX-13PL6-2926-SM-GW1SN  Breast - Mammary Tissue   40-49     44.5   F  GTEX-13PL6
# 5   GSM6586943  GTEX-147F3-1626-SM-GW1DU  Breast - Mammary Tissue   50-59     54.5   F  GTEX-147F3
# 6   GSM6586944  GTEX-14BIL-2526-SM-GW1SZ  Breast - Mammary Tissue   50-59     54.5   M  GTEX-14BIL
# 7   GSM6586945  GTEX-14BIN-1826-SM-GW1X6  Breast - Mammary Tissue   50-59     54.5   F  GTEX-14BIN
# 8   GSM6586946  GTEX-14E6C-1326-SM-GW1D1  Breast - Mammary Tissue   40-49     44.5   M  GTEX-14E6C
# 9   GSM6586947  GTEX-14H4A-2526-SM-GW1GY  Breast - Mammary Tissue   40-49     44.5   F  GTEX-14H4A
# 10  GSM6586948  GTEX-14PHY-1926-SM-GW2A6  Breast - Mammary Tissue   60-69     64.5   F  GTEX-14PHY
# 11  GSM6586949  GTEX-14PJ6-2026-SM-GW1R5  Breast - Mammary Tissue   60-69     64.5   F  GTEX-14PJ6
# 12  GSM6586950  GTEX-14PK6-1526-SM-GW21C  Breast - Mammary Tissue   70-79     74.5   F  GTEX-14PK6
# 13  GSM6586951  GTEX-15CHQ-0426-SM-GW1QF  Breast - Mammary Tissue   60-69     64.5   M  GTEX-15CHQ
# 14  GSM6586952  GTEX-15CHR-1026-SM-GW218  Breast - Mammary Tissue   50-59     54.5   M  GTEX-15CHR
# 15  GSM6586953  GTEX-15DDE-0726-SM-GW1RC  Breast - Mammary Tissue   50-59     54.5   F  GTEX-15DDE
# 16  GSM6586954  GTEX-15ER7-1626-SM-GW1VP  Breast - Mammary Tissue   20-29     24.5   F  GTEX-15ER7
# 17  GSM6586955  GTEX-15EU6-2426-SM-GW1RL  Breast - Mammary Tissue   50-59     54.5   M  GTEX-15EU6
# 18  GSM6586956  GTEX-15SHU-0826-SM-GW21B  Breast - Mammary Tissue   40-49     44.5   F  GTEX-15SHU
# 19  GSM6586957  GTEX-16NGA-0826-SM-GW1UD  Breast - Mammary Tissue   40-49     44.5   F  GTEX-16NGA
#
#                                       characteristics                 status submission_date last_update_date     type channel_count  \
# 0   sample_plate: CO-25654826 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 1   sample_plate: CO-25654826 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 2   sample_plate: CO-25654826 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 3   sample_plate: CO-25654153 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 4   sample_plate: CO-25654823 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 5   sample_plate: CO-25654153 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 6   sample_plate: CO-25654823 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 7   sample_plate: CO-25654824 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 8   sample_plate: CO-25654153 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 9   sample_plate: CO-25654154 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 10  sample_plate: CO-25655788 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 11  sample_plate: CO-25654822 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 12  sample_plate: CO-25654825 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 13  sample_plate: CO-25654822 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 14  sample_plate: CO-25654825 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 15  sample_plate: CO-25654822 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 16  sample_plate: CO-25654824 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 17  sample_plate: CO-25654822 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 18  sample_plate: CO-25654825 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
# 19  sample_plate: CO-25654823 | sample_plate_posit...  Public on Sep 16 2022     Sep 15 2022      Sep 16 2022  genomic             1
#
#             source_name_ch1  organism_ch1 molecule_ch1                               extract_protocol_ch1    label_ch1  \
# 0   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 1   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 2   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 3   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 4   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 5   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 6   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 7   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 8   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 9   Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 10  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 11  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 12  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 13  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 14  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 15  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 16  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 17  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 18  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
# 19  Breast - Mammary Tissue  Homo sapiens  genomic DNA  DNA samples were extracted from GTEx tissue sa...  Cy5 and Cy3
#
#             label_protocol_ch1 taxid_ch1                                       hyb_protocol  \
# 0   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 1   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 2   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 3   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 4   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 5   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 6   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 7   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 8   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 9   Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 10  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 11  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 12  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 13  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 14  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 15  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 16  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 17  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 18  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
# 19  Standard Illumina Protocol      9606  All samples were  prepared and analyzed in acc...
#
#                                         scan_protocol   description                                    data_processing platform_id  \
# 0   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 1   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 2   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 3   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 4   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 5   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 6   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 7   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 8   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 9   Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 10  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 11  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 12  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 13  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 14  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 15  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 16  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 17  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 18  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
# 19  Arrays were imaged using BeadArray Reader usin...  sample name:  Raw DNAm data was processed with ChAMP softwar...    GPL21145
#
#         contact_name          contact_email         contact_laboratory      contact_department      contact_institute  \
# 0   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 1   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 2   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 3   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 4   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 5   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 6   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 7   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 8   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 9   Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 10  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 11  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 12  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 13  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 14  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 15  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 16  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 17  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 18  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
# 19  Meritxell,,Oliva  meritxellop@gmail.com  Brandon Pierce & Lin Chen  Public Health Sciences  University of Chicago
#
#          contact_address contact_city contact_state contact_zip_postal_code contact_country supplementary_file data_row_count
# 0   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 1   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 2   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 3   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 4   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 5   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 6   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 7   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 8   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 9   5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 10  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 11  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 12  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 13  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 14  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 15  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 16  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 17  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 18  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# 19  5841 S. Maryland Ave      Chicago      Illinois                   60637             USA               NONE              0
# Tissue counts:
# tissue
# Colon - Transverse         224
# Lung                       223
# Ovary                      164
# Prostate                   123
# Whole Blood                 54
# Breast - Mammary Tissue     52
# Kidney - Cortex             50
# Testis                      50
# Muscle - Skeletal           47
# Name: count, dtype: int64
#
# Missingness summary (age/sex):
# age_num missing: 0 / 987
# sex missing: 0 / 987
